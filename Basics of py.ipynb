# %%
name = "G Vishnu teja"
age = 20
height = 5.11
trainer = True
institution = "Malla Reddy University"

# %%
name
# Out:
# 'G Vishnu teja'

# %%
age
# Out:
# 20

# %%
height
# Out:
# 5.11

# %%
trainer
# Out:
# True

# %%
institution
# Out:
# 'Malla Reddy University'

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(height)
# Out:
# float

# %%
type(trainer)
# Out:
# bool

# %%
type(institution)
# Out:
# str

# %%
True + 5
# Out:
# 6

# %%
False + 5
# Out:
# 5

# %%
# prompt: 8

name = "Shivakumar"
age = 20
height = 5.11
trainer = True
institution = "Malla Reddy University"

print(name)
print(age)
print(height)
print(trainer)
print(institution)
print(type(name))
print(type(age))
print(type(height))
print(type(trainer))
print(type(institution))
print(True + 5)
False + 5
# Out:
# Shivakumar
# 20
# 5.11
# True
# Malla Reddy University
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>
# 6
# 5

# %%
a = 9.7
a
# Out:
# 9.7

# %%
b = 6
b
# Out:
# 6

# %%
type(a



     )
# Out:
# float

# %%
type(b
     )
# Out:
# int

# %%
y=float(b)
y
# Out:
# 6.0

# %%
b
# Out:
# 6

# %%
a=8.9
a
# Out:
# 8.9

# %%
type(a)
# Out:
# float

# %%
s = 7
s
# Out:
# 7

# %%
str(s)
# Out:
# '7'

# %%
type(s)
# Out:
# int
