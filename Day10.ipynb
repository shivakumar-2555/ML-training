# %%
import pandas as pd
import numpy as np
import seaborn as ans
a=np.random.randint(20,50,20)

a
# Out:
# array([32, 33, 36, 28, 36, 47, 33, 34, 42, 34, 36, 49, 21, 36, 48, 25, 47,
#        44, 45, 37])

# %%
a.ndim
# Out:
# 1

# %%
pd.Series(a)
# Out:
# 0     32
# 1     33
# 2     36
# 3     28
# 4     36
# 5     47
# 6     33
# 7     34
# 8     42
# 9     34
# 10    36
# 11    49
# 12    21
# 13    36
# 14    48
# 15    25
# 16    47
# 17    44
# 18    45
# 19    37
# dtype: int64

# %%
np.random.seed(24)
b=np.random.randint(100,200,(6,5))
b
# Out:
# array([[134, 103, 164, 187, 117],
#        [117, 101, 179, 104, 199],
#        [182, 111, 199, 115, 173],
#        [118, 107, 125, 135, 195],
#        [128, 100, 112, 195, 133],
#        [101, 160, 155, 170, 197]])

# %%
b.ndim
# Out:
# 2

# %%
b.shape
# Out:
# (6, 5)

# %%
df=pd.DataFrame(b)
df
# Out:
#      0    1    2    3    4
# 0  134  103  164  187  117
# 1  117  101  179  104  199
# 2  182  111  199  115  173
# 3  118  107  125  135  195
# 4  128  100  112  195  133
# 5  101  160  155  170  197

# %%
df=pd.DataFrame(b,columns=['Roll','Name','Age','Adds','Country'])
df
# Out:
#    Roll  Name  Age  Adds  Country
# 0   134   103  164   187      117
# 1   117   101  179   104      199
# 2   182   111  199   115      173
# 3   118   107  125   135      195
# 4   128   100  112   195      133
# 5   101   160  155   170      197

# %%
df=pd.DataFrame(b,columns=['Roll','Name','Age','Adds','Country'],index=[185,192,196,217,228,261])
df
# Out:
#      Roll  Name  Age  Adds  Country
# 185   134   103  164   187      117
# 192   117   101  179   104      199
# 196   182   111  199   115      173
# 217   118   107  125   135      195
# 228   128   100  112   195      133
# 261   101   160  155   170      197

# %%
df.iloc[0,0]
# Out:
# 134

# %%
df.loc[185,'Roll']
# Out:
# 134

# %%
df.loc[185,'Adds']
# Out:
# 187

# %%
df.iloc[[1,3,4]]
# Out:
#      Roll  Name  Age  Adds  Country
# 192   117   101  179   104      199
# 217   118   107  125   135      195
# 228   128   100  112   195      133

# %%
df.iloc[[2,4]]
# Out:
#      Roll  Name  Age  Adds  Country
# 196   182   111  199   115      173
# 228   128   100  112   195      133

# %%
df
# Out:
#      Roll  Name  Age  Adds  Country
# 185   134   103  164   187      117
# 192   117   101  179   104      199
# 196   182   111  199   115      173
# 217   118   107  125   135      195
# 228   128   100  112   195      133
# 261   101   160  155   170      197

# %%
df['Age']
# Out:
# 185    164
# 192    179
# 196    199
# 217    125
# 228    112
# 261    155
# Name: Age, dtype: int64

# %%
df[['Age','Adds']]
# Out:
#      Age  Adds
# 185  164   187
# 192  179   104
# 196  199   115
# 217  125   135
# 228  112   195
# 261  155   170

# %%
df[['Adds','Age']]
# Out:
#      Adds  Age
# 185   187  164
# 192   104  179
# 196   115  199
# 217   135  125
# 228   195  112
# 261   170  155

# %%
df.loc[[185,192,196],['Adds','Age','Roll']]
# Out:
#      Adds  Age  Roll
# 185   187  164   134
# 192   104  179   117
# 196   115  199   182
