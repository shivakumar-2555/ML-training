# %%
  import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
abs=10.22557889652365895123578951222222398745
abs=long
print(abs)

# %% [markdown]
#  numpy:                      array operations,
#  pandas:                     DAta manipulation and analysis,
#  matplotlib and seaborn:     Graphical analysis,
#  sklearn MAchine leanring:   algorithms and techniques,
#  statsmodels:                Statistical analysis,
#  scipy:                      statiscial analysis,

# %%
   ```python
   import numpy as np
   import pandas as pd
   import matplotlib.pyplot as plt
   ```
   The `as np`, `as pd`, and `as plt` are aliases that make it easier to refer to the libraries in your code.
# Out:
#   File "<ipython-input-7-28e028d1659a>", line 1
#     ```python
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as pd

# %%
j=[4,45,5,6,7,5]
j
# Out:
# [4, 45, 5, 6, 7, 5]

# %%
d=np.array(j)
d
# Out:
# array([ 4, 45,  5,  6,  7,  5])

# %%
type(d)
# Out:
# numpy.ndarray

# %%
tuple(j)
# Out:
# (4, 45, 5, 6, 7, 5)

# %%
d
# Out:
# array([ 4, 45,  5,  6,  7,  5])

# %%
d.shape
# Out:
# (6,)

# %%
d.ndim
# Out:
# 1

# %%
d.size
# Out:
# 6

# %%
h=d.reshape(2,3)
h
# Out:
# array([[ 4, 45,  5],
#        [ 6,  7,  5]])

# %%
import numpy as np
a=[[9,3,4,5,6,7,],[8,4,2,2,7,8,],[3,4,6,7,8,8,7],[3,3,5,6,78,44,2,2]]
print(a)
# Out:
# [[9, 3, 4, 5, 6, 7], [8, 4, 2, 2, 7, 8], [3, 4, 6, 7, 8, 8, 7], [3, 3, 5, 6, 78, 44, 2, 2]]

# %%
type(a)
# Out:
# list

# %%
np.array(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-2c31ab10380b> in <cell line: 0>()
# ----> 1 np.array(a)
#       2
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (4,) + inhomogeneous part.

# %%
h.size
# Out:
# 6

# %%
h.shape
# Out:
# (2, 3)

# %%
h.ndim
# Out:
# 2
