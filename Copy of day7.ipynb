# %%
x=5
while x>10:
  print('data')

# %%
y=[5,6,7,3,8,2,1,4]
y
# Out:
# [5, 6, 7, 3, 8, 2, 1, 4]

# %%
y
# Out:
# [5, 6, 7, 3, 8, 2, 1, 4]

# %%
for t in y:
  print(t*98)
# Out:
# 490
# 588
# 686
# 294
# 784
# 196
# 98
# 392

# %%
for t in y:
  print(t*98+47)
# Out:
# 537
# 635
# 733
# 341
# 831
# 243
# 145
# 439

# %%
for t in y:
  print(t*98+47-145)
# Out:
# 392
# 490
# 588
# 196
# 686
# 98
# 0
# 294

# %%
for t in y:
  print(t*98+47-100/5)
# Out:
# 517.0
# 615.0
# 713.0
# 321.0
# 811.0
# 223.0
# 125.0
# 419.0

# %%
num=[31,43,98,76,82,76,95,48,83,67,56,96,24]
num
# Out:
# [31, 43, 98, 76, 82, 76, 95, 48, 83, 67, 56, 96, 24]

# %%
odd=[]
even=[]
for i in num:
  if i%2==0:
    even.append(i)
  else:
    odd.append(i)
print(odd)
print(even)
# Out:
# [31, 43, 95, 83, 67]
# [98, 76, 82, 76, 48, 56, 96, 24]

# %%
num
# Out:
# [31, 43, 98, 76, 82, 76, 95, 48, 83, 67, 56, 96, 24]

# %%
# prompt: change 8 to 5 from the elements in num

for i in range(len(num)):
  if num[i] == 8:
    num[i] == 5

num
# Out:
# [31, 43, 98, 76, 82, 76, 95, 48, 83, 67, 56, 96, 24]

# %%
for i in range(len(num)):
  if num[i] == 8:
    num[i] = 5

num
# Out:
# [31, 43, 98, 76, 82, 76, 95, 48, 83, 67, 56, 96, 24]

# %%
t=str(48)
t
# Out:
# '48'

# %%
a=t.replace("4","6")
t
int(a)
# Out:
# 68

# %%
h=[]
for i in num:
  a=str(i)
  b=a.replace("8","5")
  c=int(b)
  h.append(int(b))

# %%
print(h)
# Out:
# [31, 43, 95, 76, 52, 76, 95, 45, 53, 67, 56, 96, 24]

# %%
# Out:
# 'SolutiOns'

# %%
s = "SangareddY"
new_s = s[1:-1]
new_s
# Out:
# 'angaredd'

# %%
x='SoftwareO'
y=''

for i in x:
  if i.lower() not in ('s','o'):
    y+=i

# %%
y
# Out:
# 'ftware'
