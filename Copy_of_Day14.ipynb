# %% [markdown]
# <a href="https://colab.research.google.com/github/shivakumar-2555/ML-training/blob/main/Copy_of_Day14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df.iloc[886]
# Out:
# survived                 0
# pclass                   2
# sex                   male
# age                   27.0
# sibsp                    0
# parch                    0
# fare                  13.0
# embarked                 S
# class               Second
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                 True
# Name: 886, dtype: object

# %%
df.sample()
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked  class    who  \
# 683         0       3  male  14.0      5      2  46.9        S  Third  child
#
#      adult_male deck  embark_town alive  alone
# 683       False  NaN  Southampton    no  False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.info(['object'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df['alive'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['alive'].value_counts()
# Out:
# alive
# no     549
# yes    342
# Name: count, dtype: int64

# %%
df[df.duplicated()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 47          1       3  female   NaN      0      0   7.7500        Q   Third
# 76          0       3    male   NaN      0      0   7.8958        S   Third
# 77          0       3    male   NaN      0      0   8.0500        S   Third
# 87          0       3    male   NaN      0      0   8.0500        S   Third
# 95          0       3    male   NaN      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.duplicated().sum()
# Out:
# 107

# %%
df.drop_duplicates()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.reset_index()
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 4        4         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 779    885         0       3  female  39.0      0      5  29.1250        Q
# 780    887         1       1  female  19.0      0      0  30.0000        S
# 781    888         0       3  female   NaN      1      2  23.4500        S
# 782    889         1       1    male  26.0      0      0  30.0000        C
# 783    890         0       3    male  32.0      0      0   7.7500        Q
#
#      class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.reset_index(drop=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 779         0       3  female  39.0      0      5  29.1250        Q  Third
# 780         1       1  female  19.0      0      0  30.0000        S  First
# 781         0       3  female   NaN      1      2  23.4500        S  Third
# 782         1       1    male  26.0      0      0  30.0000        C  First
# 783         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 779         0       3  female  39.0      0      5  29.1250        Q  Third
# 780         1       1  female  19.0      0      0  30.0000        S  First
# 781         0       3  female   NaN      1      2  23.4500        S  Third
# 782         1       1    male  26.0      0      0  30.0000        C  First
# 783         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# prompt: Using dataframe df: missing values

# Check for missing values in each column
print(df.isnull().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            106
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           582
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            106
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           582
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 768         1       1  female  47.0      1      1  52.5542        S  First
# 769         0       1    male  33.0      0      0   5.0000        S  First
# 774         1       1  female  56.0      0      1  83.1583        C  First
# 780         1       1  female  19.0      0      0  30.0000        S  First
# 782         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.reset_index()
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        3         1       1  female  35.0      1      0  53.1000        S
# 4        4         0       3    male  35.0      0      0   8.0500        S
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 779    779         0       3  female  39.0      0      5  29.1250        Q
# 780    780         1       1  female  19.0      0      0  30.0000        S
# 781    781         0       3  female   NaN      1      2  23.4500        S
# 782    782         1       1    male  26.0      0      0  30.0000        C
# 783    783         0       3    male  32.0      0      0   7.7500        Q
#
#      class    who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.heatmap(df.isnull())# missing or zero values
# Out:
# <Axes: >

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 779         0       3  female  39.0      0      5  29.1250        Q  Third
# 780         1       1  female  19.0      0      0  30.0000        S  First
# 781         0       3  female   NaN      1      2  23.4500        S  Third
# 782         1       1    male  26.0      0      0  30.0000        C  First
# 783         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.drop('age',axis=1,inplace=True)

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
df['embark_town'].mode()
# Out:
# 0    Southampton
# Name: embark_town, dtype: object

# %%
df['embark_town'].mode()[0]
# Out:
# 'Southampton'

# %%
df['embark_town'].isnull().sum()
# Out:
# 2

# %%
#filling missing positions
df['embark_town'].fillna('Southampton')
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 779     Queenstown
# 780    Southampton
# 781    Southampton
# 782      Cherbourg
# 783     Queenstown
# Name: embark_town, Length: 784, dtype: object

# %%
df['embark_town'].fillna(df['embark_town'].mode()[0])
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 779     Queenstown
# 780    Southampton
# 781    Southampton
# 782      Cherbourg
# 783     Queenstown
# Name: embark_town, Length: 784, dtype: object

# %%
df['embark_town'].fillna(df['embark_town'].mode()[0],inplace=True)

# %%
df
# Out:
#      survived  pclass     sex  sibsp  parch     fare embarked  class    who  \
# 0           0       3    male      1      0   7.2500        S  Third    man
# 1           1       1  female      1      0  71.2833        C  First  woman
# 2           1       3  female      0      0   7.9250        S  Third  woman
# 3           1       1  female      1      0  53.1000        S  First  woman
# 4           0       3    male      0      0   8.0500        S  Third    man
# ..        ...     ...     ...    ...    ...      ...      ...    ...    ...
# 779         0       3  female      0      5  29.1250        Q  Third  woman
# 780         1       1  female      0      0  30.0000        S  First  woman
# 781         0       3  female      1      2  23.4500        S  Third  woman
# 782         1       1    male      0      0  30.0000        C  First    man
# 783         0       3    male      0      0   7.7500        Q  Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
df['embark_town'].isnull().sum()
# Out:
# 0

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['embarked'].isnull().sum()
# Out:
# 2

# %%
df['embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['embarked'].mode()[0]
# Out:
# 'S'

# %%
df['embarked'].fillna('S')
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 779    Q
# 780    S
# 781    S
# 782    C
# 783    Q
# Name: embarked, Length: 784, dtype: object

# %%
df['embarked'].isnull().sum()
# Out:
# 2

# %%
df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)

# %%
df['embarked'].isnull().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#          survived      pclass       sibsp       parch        fare
# count  784.000000  784.000000  784.000000  784.000000  784.000000
# mean     0.411990    2.243622    0.522959    0.415816   34.711740
# std      0.492507    0.855056    0.986231    0.836922   52.160151
# min      0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000    0.000000    0.000000    8.050000
# 50%      0.000000    3.000000    0.000000    0.000000   15.900000
# 75%      1.000000    3.000000    1.000000    1.000000   34.109350
# max      1.000000    3.000000    8.000000    6.000000  512.329200

# %%
df.describe(include="O")
# Out:
#          sex embarked  who  embark_town alive
# count    784      784  784          784   784
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     491      570  451          570   461

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# prompt: remove missing values of age using mean

# Calculate the mean of the 'age' column, ignoring missing values
mean_age = df['age'].mean()

# Fill missing 'age' values with the calculated mean
df['age'].fillna(mean_age, inplace=True)

# Verify that there are no more missing values in the 'age' column
print(df.isnull().sum())

# Display the updated DataFrame (optional)
#print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-f3bf9e10e6c9> in <cell line: 0>()
#       2
# ...

# %%
df["age"].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-661ef25eca6e> in <cell line: 0>()
# ----> 1 df["age"].mean()
#
# ...

# %%
df['age'].fillna('29.869351032448375',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-5781975dcdf3> in <cell line: 0>()
# ----> 1 df['age'].fillna('29.869351032448375',inplace=True)
#
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
s=0
c=2
q=1

# %%
df['embarked'].replace({'S':12,'C':34,'Q':30},inplace=True)

# %%
df['embarked'].unique()
# Out:
# array([12, 34, 30])

# %%
df['embarked']
# Out:
# 0      12
# 1      34
# 2      12
# 3      12
# 4      12
#        ..
# 779    30
# 780    12
# 781    12
# 782    34
# 783    30
# Name: embarked, Length: 784, dtype: int64

# %%
df['embarked'].unique()
# Out:
# array([12, 34, 30])

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['embarked']=lb.fit_transform(df['embarked'])

# %%
df['embarked'].unique()
# Out:
# array([0, 2, 1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 784 entries, 0 to 783
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     784 non-null    int64
#  1   pclass       784 non-null    int64
#  2   sex          784 non-null    object
#  3   sibsp        784 non-null    int64
#  4   parch        784 non-null    int64
#  5   fare         784 non-null    float64
#  6   embarked     784 non-null    int64
#  7   class        784 non-null    category
#  8   who          784 non-null    object
#  9   adult_male   784 non-null    bool
#  10  deck         202 non-null    category
#  11  embark_town  784 non-null    object
#  12  alive        784 non-null    object
#  13  alone        784 non-null    bool
# dtypes: bool(2), category(2), float64(1), int64(5), object(4)
# memory usage: 64.9+ KB

# %%
df['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['sex']=lb.fit_transform(df['sex'])

# %%
df['sex'].unique()
# Out:
# array([1, 0])

# %%
df['class'].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
df['class']=lb.fit_transform(df['class'])

# %%
df['class'].unique()
# Out:
# array([2, 0, 1])

# %%
df['who'].unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
df['who']=lb.fit_transform(df['who'])

# %%
df['who'].unique()
# Out:
# array([1, 2, 0])

# %%
df['deck'].unique()
# Out:
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
df['deck']=lb.fit_transform(df['deck'])

# %%
df['deck'].unique()
# Out:
# array([7, 2, 4, 6, 3, 0, 1, 5])

# %%
df['alive'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
oh_species=pd.get_dummies(df['species'])
df=pd.concat([df.drop('species',axis=1),oh_species],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'species'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-b6661e2c0080> in <cell line: 0>()
# ----> 1 oh_species=pd.get_dummies(df['species'])
# ...

# %%
df
# Out:
#      survived  pclass  sex  sibsp  parch     fare  embarked  class  who  \
# 0           0       3    1      1      0   7.2500         0      2    1
# 1           1       1    0      1      0  71.2833         2      0    2
# 2           1       3    0      0      0   7.9250         0      2    2
# 3           1       1    0      1      0  53.1000         0      0    2
# 4           0       3    1      0      0   8.0500         0      2    1
# ..        ...     ...  ...    ...    ...      ...       ...    ...  ...
# 779         0       3    0      0      5  29.1250         1      2    2
# 780         1       1    0      0      0  30.0000         0      0    2
# 781         0       3    0      1      2  23.4500         0      2    2
# 782         1       1    1      0      0  30.0000         2      0    1
# 783         0       3    1      0      0   7.7500         1      2    1
#
#      adult_male  deck  embark_town alive  alone
# 0          True     7  Southampton    no  False
# ...
