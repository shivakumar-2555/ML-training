# %%
#Conditional statements
x=10
if x>0:
  print("x is positive number")
else:
  print("x is Negative number")
# Out:
# x is positive number

# %%
#Cnditional statements
x=-22
if x>0:
  print("x is positive number")
elif x<0:
  print("x is Negative number")
else:
  print("x is zero")
# Out:
# x is Negative number

# %%
#String functions
a="Bangolure"
a.upper()
# Out:
# 'BANGOLURE'

# %%
a.isalpha()
# Out:
# True

# %%
a[-2:3:-4]
# Out:
# 'r'

# %%
x=str(input())
if x[0]=="S" or x[0]=="s":
  print("yes")
elif x[0]=="T" or x[0]=="t":
  print("yes")
else:
    print("no")

# %%
x=str(input())
if x[0]=="S" or x[0]=="s" or x[0]=="T" or x[0]=="t" or x[0]=="H" or x[0]=="h"
  print("yes")
else:
    print("no")
