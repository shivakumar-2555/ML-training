# %%
a=['Shivakumar',123,'Hyderabad',87,98.876,'lithium']

# %%
a[3]
# Out:
# 87

# %%
a[-3]
# Out:
# 87

# %%
a[-5]
# Out:
# 123

# %%
a[1]
# Out:
# 123

# %%
a[1:4]
# Out:
# [123, 'Hyderabad', 87]

# %%
a[0]
# Out:
# 'Shivakumar'

# %%
#slicing

# %%
a[2:6]
# Out:
# ['Hyderabad', 87, 98.876, 'lithium']

# %%
a[2:7]# 7th element will be excludede
# Out:
# ['Hyderabad', 87, 98.876, 'lithium']

# %%
a[2:90]
# Out:
# ['Hyderabad', 87, 98.876, 'lithium']

# %%
a[-2:90]
# Out:
# [98.876, 'lithium']

# %%
a[-3::90]
# Out:
# [87]

# %%
a[-3::90]
# Out:
# [87]

# %%
a[-3:90]
# Out:
# [87, 98.876, 'lithium']

# %%
a[-7:-2]# -2 idex value will be excluded
# Out:
# ['Shivakumar', 123, 'Hyderabad', 87]

# %%
type(a)
# Out:
# list

# %%
a
# Out:
# ['Shivakumar', 123, 'Hyderabad', 87, 98.876, 'lithium']

# %%
a[-2]
# Out:
# 98.876

# %%
a[2]
# Out:
# 'Hyderabad'

# %%
a[-4]
# Out:
# 'Hyderabad'

# %%
a[0:6:1]#stacking : skipping the position
# Out:
# ['Shivakumar', 123, 'Hyderabad', 87, 98.876, 'lithium']

# %%
a[0:6:3]
# Out:
# ['Shivakumar', 87]

# %%
a[0:6:2]
# Out:
# ['Shivakumar', 'Hyderabad', 98.876]

# %%
a
# Out:
# ['Shivakumar', 123, 'Hyderabad', 87, 98.876, 'lithium']

# %%
a[-2:0]# we wont get any output
# Out:
# []

# %%
append
insert
extend
pop
remove
clear
count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-177fe2a0b989> in <cell line: 1>()
# ----> 1 append
#       2 insert
#       3 extend
#       4 pop
#       5 remove
#
# NameError: name 'append' is not defined

# %%
a
# Out:
# ['Shivakumar', 123, 'Hyderabad', 87, 98.876, 'lithium']

# %%
a.append(765) #add values or elements at last

# %%
a
# Out:
# ['Shivakumar', 123, 'Hyderabad', 87, 98.876, 'lithium', 765]

# %%
a.append('Gaggu')

# %%
a
# Out:
# ['Shivakumar', 123, 'Hyderabad', 87, 98.876, 'lithium', 765, 'Gaggu']

# %%
a.append('India')

# %%
a
# Out:
# ['Shivakumar', 123, 'Hyderabad', 87, 98.876, 'lithium', 765, 'Gaggu', 'India']

# %%
a.insert(1,'Yadav')

# %%
a
# Out:
# ['Shivakumar',
#  'Yadav',
#  123,
#  'Hyderabad',
#  87,
#  98.876,
#  'lithium',
#  765,
#  'Gaggu',
#  'India']

# %%
a.insert(10,'End')

# %%
a
# Out:
# ['Shivakumar',
#  'Yadav',
#  123,
#  'Hyderabad',
#  87,
#  98.876,
#  'lithium',
#  765,
#  'Gaggu',
#  'India',
#  'End']

# %%
print(a)# to get in vertical
# Out:
# ['Shivakumar', 'Yadav', 123, 'Hyderabad', 87, 98.876, 'lithium', 765, 'Gaggu', 'India', 'End']
